# %% [markdown]
# ## Práctica 1 – Tema 1: Primeros pasos en Python
# ### Instrucciones generales
#
# Esta práctica tiene como propósito reforzar los conceptos vistos en el Tema 1. Deberás realizar los ejercicios paso a paso utilizando el archivo 'SuperMarket Analysis.csv'. El trabajo debe desarrollarse en un Notebook (.ipynb) dentro de VS Code o Jupyter.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque 1 – Configuración inicial
# **Objetivo:** verificar instalación y entorno de trabajo.
#
# 1. Crear un nuevo notebook llamado 'Practica_Tema1.ipynb'.
# 2. Importar las librerías necesarias:
#
#   - import pandas as pd
#
#   - import numpy as np
#
#   - import matplotlib.pyplot as plt
#
# 3. Mostrar un mensaje de confirmación de entorno.
# 4. Imprimir las versiones de las librerías instaladas.
#
# Pregunta: ¿Por qué es importante trabajar dentro de un entorno virtual (venv)?

# %%
# Punto 2
# !pip install numpy
# !python3 -m pip install numpy

# !pip install pandas
# !python3 -m pip install pandas

# !pip install matplotlib
# !python3 -m pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#   Using cached pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Punto 3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Punto 4
print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)
print("matplotlib version:", plt.__version__)
# Out:
# numpy version: 2.2.6
# pandas version: 2.3.3
# matplotlib version: 3.10.7

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque 2 – Carga y exploración del dataset
# **Objetivo:** importar y conocer la estructura del dataset.
#
# 1. Cargar el archivo 'SuperMarket Analysis.csv'.
# 2. Eliminar espacios en los nombres de columnas.
# 3. Mostrar:
#   - Primeras 5 filas.
#   - Dimensiones del dataset (df.shape).
#   - Tipos de datos (df.info()).
#   - Estadísticas básicas (df.describe()).

# %%
# Punto 1: Cargar el archivo
df_SuperMarketAnalysis_csv = pd.read_csv('./data/SuperMarketAnalysis.csv')

# %%
# Punto 2: Eliminar espacios en los nombres de columnas
df_SuperMarketAnalysis_csv.columns = df_SuperMarketAnalysis_csv.columns.str.replace(' ', '')

# %%
# Punto 3: Primeras 5 filas
df_SuperMarketAnalysis_csv.head()
# Out:
#      InvoiceID Branch       City Customertype  Gender             Productline  \
# 0  750-67-8428   Alex     Yangon       Member  Female       Health and beauty
# 1  226-31-3081   Giza  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108   Alex     Yangon       Normal  Female      Home and lifestyle
# 3  123-19-1176   Alex     Yangon       Member  Female       Health and beauty
# 4  373-73-7910   Alex     Yangon       Member  Female       Sports and travel
#
#    Unitprice  Quantity    Tax5%     Sales       Date         Time  \
# 0      74.69         7  26.1415  548.9715   1/5/2019   1:08:00 PM
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29:00 AM
# 2      46.33         7  16.2155  340.5255   3/3/2019   1:23:00 PM
# 3      58.22         8  23.2880  489.0480  1/27/2019   8:33:00 PM
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37:00 AM
#
#        Payment    cogs  grossmarginpercentage  grossincome  Rating
# ...

# %%
# Punto 3: Dimensiones del dataset
df_SuperMarketAnalysis_csv.shape
# Out:
# (1000, 17)

# %%
# Punto 3: Tipo de datos

df_SuperMarketAnalysis_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InvoiceID              1000 non-null   object
#  1   Branch                 1000 non-null   object
#  2   City                   1000 non-null   object
#  3   Customertype           1000 non-null   object
#  4   Gender                 1000 non-null   object
#  5   Productline            1000 non-null   object
#  6   Unitprice              1000 non-null   float64
#  7   Quantity               1000 non-null   int64
#  8   Tax5%                  1000 non-null   float64
#  9   Sales                  1000 non-null   float64
#  10  Date                   1000 non-null   object
#  11  Time                   1000 non-null   object
#  12  Payment                1000 non-null   object
#  13  cogs                   1000 non-null   float64
# ...

# %%
# Punto 3: Estadísticas

df_SuperMarketAnalysis_csv.describe()
# Out:
#          Unitprice     Quantity        Tax5%        Sales        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        grossmarginpercentage  grossincome      Rating
# count            1000.000000  1000.000000  1000.00000
# mean                4.761905    15.379369     6.97270
# std                 0.000000    11.708825     1.71858
# min                 4.761905     0.508500     4.00000
# 25%                 4.761905     5.924875     5.50000
# ...

# %%
## Correlacion de datos
df_SuperMarketAnalysis_csv.select_dtypes(include=('int64','float64')).corr()
# Out:
#                        Unitprice  Quantity     Tax5%     Sales      cogs  \
# Unitprice               1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                0.010778  1.000000  0.705510  0.705510  0.705510
# Tax5%                   0.633962  0.705510  1.000000  1.000000  1.000000
# Sales                   0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                    0.633962  0.705510  1.000000  1.000000  1.000000
# grossmarginpercentage        NaN       NaN       NaN       NaN       NaN
# grossincome             0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                 -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                        grossmarginpercentage  grossincome    Rating
# Unitprice                                NaN     0.633962 -0.008778
# Quantity                                 NaN     0.705510 -0.015815
# Tax5%                                    NaN     1.000000 -0.036442
# ...

# %% [markdown]
# ### Preguntas:
#
# • ¿Cuántas filas y columnas tiene el dataset?
#
# Tiene **1000** filas y **17** columnas
#
# • ¿Qué tipo de información contiene?
#
# Se compone de objetos, numeros enteros (int64) y flotantes (float64)
#
# • ¿Qué variables parecen más relevantes para las ventas?
#
# Usando una matriz de correlación, podemos ver que Quantity, Tax5% y grossincome son los que parecen más relevantes, especialmente los dos últimos mencionados.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque 3 – Limpieza y manipulación de datos
# **Objetivo:** transformar y preparar los datos para el análisis.
#
# 1. Eliminar filas duplicadas.
# 2. Crear una nueva columna llamada 'Net Sales' = 'Sales' - 'Tax 5%'.
# 3. Calcular:
#   - Promedio de ventas.
#   - Ventas totales.
# 4. Filtrar las transacciones donde las ventas sean mayores a 500.
# 5. Ordenar las ventas por sucursal de forma descendente.
#
# Preguntas:
# • ¿Qué porcentaje del total representan las ventas mayores a $500?
# • ¿Cuál es el promedio de Rating por tipo de cliente?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %%
# Punto 1: Eliminar filas duplicadas
df_SuperMarketAnalysis_csv.drop_duplicates()
# Out:
#        InvoiceID Branch       City Customertype  Gender  \
# 0    750-67-8428   Alex     Yangon       Member  Female
# 1    226-31-3081   Giza  Naypyitaw       Normal  Female
# 2    631-41-3108   Alex     Yangon       Normal  Female
# 3    123-19-1176   Alex     Yangon       Member  Female
# 4    373-73-7910   Alex     Yangon       Member  Female
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758   Giza  Naypyitaw       Normal    Male
# 996  303-96-2227  Cairo   Mandalay       Normal  Female
# 997  727-02-1313   Alex     Yangon       Member    Male
# 998  347-56-2442   Alex     Yangon       Normal    Male
# 999  849-09-3807   Alex     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity    Tax5%      Sales  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
# Punto 2: Nueva columna 'Net Sales' = 'Sales' - 'Tax 5%'.
df_SuperMarketAnalysis_csv['Net Sales'] = df_SuperMarketAnalysis_csv['Sales'] - df_SuperMarketAnalysis_csv['Tax5%']
df_SuperMarketAnalysis_csv.head()
# Out:
#      InvoiceID Branch       City Customertype  Gender             Productline  \
# 0  750-67-8428   Alex     Yangon       Member  Female       Health and beauty
# 1  226-31-3081   Giza  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108   Alex     Yangon       Normal  Female      Home and lifestyle
# 3  123-19-1176   Alex     Yangon       Member  Female       Health and beauty
# 4  373-73-7910   Alex     Yangon       Member  Female       Sports and travel
#
#    Unitprice  Quantity    Tax5%     Sales       Date         Time  \
# 0      74.69         7  26.1415  548.9715   1/5/2019   1:08:00 PM
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29:00 AM
# 2      46.33         7  16.2155  340.5255   3/3/2019   1:23:00 PM
# 3      58.22         8  23.2880  489.0480  1/27/2019   8:33:00 PM
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37:00 AM
#
#        Payment    cogs  grossmarginpercentage  grossincome  Rating  Net Sales
# ...

# %%
# Punto 3: Calcular promedio de ventas
print("Promedio de ventas:", df_SuperMarketAnalysis_csv['Sales'].mean())
# Out:
# Promedio de ventas: 322.966749

# %%
# Punto 3: Calcular ventas totales
print("Ventas totales:", df_SuperMarketAnalysis_csv['Sales'].sum())
# Out:
# Ventas totales: 322966.749

# %%
# Punto 4: Filtrar las transacciones donde las ventas sean mayores a 500.

df_SuperMarketAnalysis_csv[df_SuperMarketAnalysis_csv['Sales'] > 500]
# Out:
#        InvoiceID Branch       City Customertype  Gender  \
# 0    750-67-8428   Alex     Yangon       Member  Female
# 4    373-73-7910   Alex     Yangon       Member  Female
# 5    699-14-3026   Giza  Naypyitaw       Member  Female
# 7    315-22-5665   Giza  Naypyitaw       Member  Female
# 14   829-34-3910   Alex     Yangon       Member  Female
# ..           ...    ...        ...          ...     ...
# 988  267-62-7380   Giza  Naypyitaw       Member    Male
# 989  430-53-4718  Cairo   Mandalay       Member    Male
# 991  602-16-6955  Cairo   Mandalay       Normal  Female
# 996  303-96-2227  Cairo   Mandalay       Normal  Female
# 999  849-09-3807   Alex     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity    Tax5%      Sales  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 4         Sports and travel      86.31         7  30.2085   634.3785
# 5    Electronic accessories      85.39         7  29.8865   627.6165
# ...

# %%
# Punto 5: Ordenar las ventas por sucursal de forma descendente.

df_SuperMarketAnalysis_csv.sort_values(by='Branch', ascending=False)
# Out:
#        InvoiceID Branch       City Customertype  Gender  \
# 868  631-34-1880   Giza  Naypyitaw       Member    Male
# 276  526-86-8552   Giza  Naypyitaw       Member  Female
# 569  408-26-9866   Giza  Naypyitaw       Normal  Female
# 287  226-71-3580   Giza  Naypyitaw       Normal  Female
# 286  593-95-4461   Giza  Naypyitaw       Member    Male
# ..           ...    ...        ...          ...     ...
# 475  502-05-1910   Alex     Yangon       Normal    Male
# 474  676-39-6028   Alex     Yangon       Member  Female
# 472  405-31-3305   Alex     Yangon       Member    Male
# 471  340-21-9136   Alex     Yangon       Member  Female
# 999  849-09-3807   Alex     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity    Tax5%     Sales  \
# 868      Food and beverages      24.31         3   3.6465   76.5765
# 276      Home and lifestyle      21.82        10  10.9100  229.1100
# 569       Sports and travel      73.98         7  25.8930  543.7530
# ...

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque 4 – Agrupación y análisis
# **Objetivo:** aplicar operaciones de agrupamiento y resumen.
#
# 1. Calcular las ventas totales por sucursal.
# 2. Calcular el promedio de calificación por método de pago.
# 3. Determinar el producto más vendido (por cantidad total).
# 4. Identificar el ingreso bruto promedio por ciudad.
#
# Reto adicional: combinar varios cálculos en una sola instrucción con agg():
# df.groupby('Branch').agg(Total_Sales=('Sales', 'sum'), Avg_Rating=('Rating', 'mean'), Avg_Gross=('gross income', 'mean'))

# %%
# Punto 1: Calcular las ventas totales por sucursal

ventas_totales_branch = df_SuperMarketAnalysis_csv.groupby('Branch')["Sales"].sum()
ventas_totales_branch
# Out:
# Branch
# Alex     106200.3705
# Cairo    106197.6720
# Giza     110568.7065
# Name: Sales, dtype: float64

# %%
# Punto 2: Calcular el promedio de calificación por método de pago

promedio_calificacion_metodoPago = df_SuperMarketAnalysis_csv.groupby('Payment')['Rating'].mean()
promedio_calificacion_metodoPago
# Out:
# Payment
# Cash           6.970058
# Credit card    7.003215
# Ewallet        6.947826
# Name: Rating, dtype: float64

# %%
# Punto 3: Determinar el producto más vendido (por cantidad total)

producto_mas_vendido = df_SuperMarketAnalysis_csv.groupby('Productline')['Quantity'].sum().sort_values(ascending=False)
producto_mas_vendido.head(1)
# Out:
# Productline
# Electronic accessories    971
# Name: Quantity, dtype: int64

# %%
# Punto 4: Ingreso bruto promedio por ciudad

promedio_ingresoBruto_ciudad = df_SuperMarketAnalysis_csv.groupby('City')['grossincome'].mean()
promedio_ingresoBruto_ciudad
# Out:
# City
# Mandalay     15.232024
# Naypyitaw    16.052367
# Yangon       14.874001
# Name: grossincome, dtype: float64

# %%
# Reto adicional: combinar varios cálculos en una sola instrucción con agg()

branch_totalSales_avgRating_avgGross = df_SuperMarketAnalysis_csv.groupby('Branch').agg(Total_Sales=('Sales', 'sum'), Avg_Rating=('Rating', 'mean'), Avg_Gross=('grossincome', 'mean'))
branch_totalSales_avgRating_avgGross
# Out:
#         Total_Sales  Avg_Rating  Avg_Gross
# Branch
# Alex    106200.3705    7.027059  14.874001
# Cairo   106197.6720    6.818072  15.232024
# Giza    110568.7065    7.072866  16.052367

# %% [markdown]
# ### Preguntas:
# • ¿Qué sucursal genera mayores ingresos?
#
# La sucursal de Giza
#
# • ¿Qué método de pago muestra mejor calificación promedio?
#
# El pago con tarjeta de crédito

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque 5 – Visualización básica
# **Objetivo:** representar los resultados gráficamente con Matplotlib.
#
# 1. Crear un gráfico de barras con las ventas totales por sucursal.
# 2. Crear un histograma con la distribución de calificaciones (Rating).
# 3. Crear un gráfico circular con la proporción de métodos de pago.
# 4. Personalizar los gráficos agregando títulos, etiquetas y estilo 'seaborn-v0_8'.
#
# Reto adicional: comparar las ventas promedio por tipo de cliente en un solo gráfico.
#
# Preguntas:
# • ¿Qué conclusiones se pueden obtener de los gráficos generados?
# • ¿Qué visualización consideras más útil para un reporte gerencial?

# %%
# Punto 1: Gráfico de barras con las ventas totales por sucursal

ventas_totales_branch.plot(kind='bar', color='darkgreen')
plt.title('Ventas Totales')
plt.ylabel('Monto en $$$')
plt.style.use('seaborn-v0_8')
plt.show()

# %%
# Punto 2: Histograma con la distribución de calificaciones (Rating)
df_SuperMarketAnalysis_csv['Rating'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
#plt.hist(df_SuperMarketAnalysis_csv['Rating'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribución de calificaciones (Rating)')
plt.ylabel('Cantidad de Calificaciones')
plt.xlabel('Prome')
plt.style.use('seaborn-v0_8')
plt.show()

# %%
# Out:
# Payment
# Ewallet        34.5
# Cash           34.4
# Credit card    31.1
# Name: proportion, dtype: float64

# %%
# Punto 3: Gráfico circular con la proporción de métodos de pago

# Obtener la proporción
proporcion_metodoPago = df_SuperMarketAnalysis_csv['Payment'].value_counts(normalize=True) * 100
proporcion_metodoPago

# Gráfico
proporcion_metodoPago.plot(kind='pie', autopct='%1.1f%%')
plt.title('Proporción de métodos de pago')
plt.ylabel('')
#plt.gca().set_ylabel(None)
plt.style.use('seaborn-v0_8')
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Bloque opcional – Reflexión final
# Responde brevemente:
#
# • ¿Qué variables parecen influir más en las ventas totales?
#
# • ¿Qué patrones observas entre sucursal y calificación?
#
# • ¿Qué podría mejorar el supermercado según tus hallazgos?
